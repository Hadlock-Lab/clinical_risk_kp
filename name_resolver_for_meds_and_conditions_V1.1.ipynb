# %%
## Following are code for name resolver on conditions

# %%
import requests
import collections
import json

nr_url = 'https://name-resolution-sri.renci.org/lookup'
list_to_query =['cystic_fibrosis', 'ehlers_danlos_syndrome', 'diabetes_mellitus_type_2', 'chronic_heart_failure', 'chronic_hypertension', 'osteoarthritis', 'chronic_obstructive_pulmonary_disease', 'chronic_ischemic_heart_disease', 'chronic_kidney_disease', 'osteoporosis', 'hyperlipidemia', 'atrial_fibrillation', 'chronic_hepatitis_b_c', 'obesity_disorder', 'hiv', 'psoriatic_arthritis', 'psoriasis', 'rheumatoid_arthritis', 'narcolepsy', 'fabry_disease', 'primary_biliary_cholangitis', 'bethlem_myopathy', 'cerebral_autosomal_dominant_arteriopathy_with_subcortical_infarcts_and_leukoencephalopathy', 'hypermobile_ehlers_danlos_syndrome', 'vascular_ehlers_danlos_syndrome', 'ehlers_danlos_syndrome_kyphoscoliotic_type', 'ehlers_danlos_syndrome_procollagen_proteinase_deficient', 'classical_ehlers_danlos_syndrome', 'hereditary_insensitivity_to_pain_with_anhidrosis', 'inclusion_body_myositis', 'ullrich_congenital_muscular_dystrophy', 'fatal_familial_insomnia', 'castleman_disease', 'hemophilia', 'spinal_muscular_atrophy', 'retinal_dystrophy', 'familial_x_linked_hypophosphatemic_vitamin_d_refractory_rickets', 'adrenal_cushing_syndrome', 'pulmonary_hypertensive_arterial_disease', 'brugada_syndrome', 'erythropoietic_protoporphyria', 'guillain_barre_syndrome', 'familial_malignant_melanoma_of_skin', 'tetralogy_of_fallot', 'discordant_ventriculoarterial_connection', 'focal_dystonia', 'marfan_syndrome', 'non_hodgkin_lymphoma', 'retinitis_pigmentosa', 'gelineau_syndrome', 'multiple_myeloma', 'alpha_1_antitrypsin_deficiency', 'congenital_diaphragmatic_hernia', 'juvenile_idiopathic_arthritis', 'neurofibromatosis_type_1', 'congenital_atresia_of_esophagus', 'polycythemia_vera', 'hereditary_motor_and_sensory_neuropathy', 'polycystic_kidney_disease_infantile_type', 'vater_association', 'coffin_lowry_syndrome', 'osler_hemorrhagic_telangiectasia_syndrome', 'dermatitis_herpetiformis', 'congenital_atresia_of_small_intestine', 'congenital_atresia_of_duodenum', 'congenital_aganglionic_megacolon', '22q11_2_deletion_syndrome', 'hereditary_spherocytosis', 'turner_syndrome', 'melas', 'hyperleucinemia', 'medium_chain_acyl_coenzyme_a_dehydrogenase_deficiency', 'lennox_gastaut_syndrome', 'fragile_x_syndrome', 'stickler_syndrome', 'williams_syndrome', 'von_willebrand_disorder', 'gastroschisis', 'microphthalmos', 'congenital_omphalocele', 'sarcoidosis', 'stargardt_disease', 'glioblastoma_multiforme', 'multiple_endocrine_neoplasia_type_1', 'prader_willi_syndrome', 'alopecia_totalis', 'nephroblastoma', 'duane_syndrome', 'neuroblastoma', 'hodgkin_disease', 'parkes_weber_syndrome', 'klippel_trenaunay_syndrome', 'whipple_disease', 'incontinentia_pigmenti_syndrome', 'aicardi_syndrome', 'white_matter_disorder_with_cadasil', 'li_fraumeni_syndrome', 'russell_silver_syndrome', 'congenital_livedo_reticularis', 'moebius_syndrome', 'alstrom_syndrome', 'kabuki_make_up_syndrome', 'ondine_curse', 'job_syndrome', 'kearns_sayre_syndrome', 'cholestanol_storage_disease', 'cockayne_syndrome', 'congenital_erythropoietic_porphyria', 'cogan_syndrome', 'kimura_disease', 'alcohol_abuse', 'alcoholic_liver_disease', 'allergic_rhinitis', 'alzheimers_disease', 'ankylosing_spondyloarthritis', 'arteriosclerosis', 'asthma', 'attention_deficit_hyperactivity_disorder', 'autoimmune_liver_disease', 'carotid_atherosclerosis', 'celiac_disease', 'cerebral_atherosclerosis', 'chronic_depression', 'chronic_fatigue_syndrome', 'chronic_hepatitis_b', 'chronic_hepatitis_c', 'chronic_kidney_disease_v', 'complex_regional_pain_syndrome_', 'chronic_obstructive_lung_disease', 'crohns_disease', 'diabetes_type_1', 'diabetes_type_2', 'endometriosis_', 'eczema', 'fibromyalgia_', 'gerd', 'gout', 'graves_disease', 'heart_failure', 'heart_valve_disease', 'herpes_simplex', 'huntingtons_disease', 'hyperglycemia', 'hyperthyroidism', 'menieres_disease', 'multiple_sclerosis', 'nonalcoholic_steatohepatitis', 'obesity', 'obsessive_compulsive_disorder', 'parkinsons_disease', 'peripheral_arterial_disease', 'peripheral_neuropathy', 'polycystic_ovarian_disease', 'posttraumatic_stress_disorder', 'psoriasis_without_psoriatic_arthritis', 'pulmonary_hypertension', 'rosacea', 'scoliosis', 'systemic_lupus_erythematosus', 'trigeminal_neuralgia', 'ulcerative_colitis', 'vascular_dementia', 
                'vasculitis', 'vitamin_b12_deficiency']
list_curies = collections.defaultdict(dict)
for item in list_to_query:
    params = {'string':item, 'limit':1} # limit -1 makes this return all available equivalent CURIEs name resolver can give            
    r = requests.post(nr_url, params=params)
    ## Create the curies id entry & convert the list into a string
    curies = ''.join( list( r.json().keys() ) )
    list_curies[item]["id"] = curies
    ## Remove the _ symbol from the item name to get the more readable name
    readable_name = item.replace("_", " ")
    list_curies[item]["name"] = readable_name
    ## The logic to get the most accurate category based on the found curies
    if "MONDO:" or "UMLS:" in curies:
        cat = "biolink:Disease"
    elif "FB:" or "HP:" in curies:
        cat = "biolink:PhenotypicFeature"
    else:
        cat = "biolink:Disease"
    list_curies[item]["category"] = cat
    list_curies[item]["cc_list"] = [item]

# %%
print(list_curies)
# Out:
# defaultdict(<class 'dict'>, {'cystic_fibrosis': {'id': 'MONDO:0009061', 'name': 'cystic fibrosis', 'category': 'biolink:Disease', 'cc_list': ['cystic_fibrosis']}, 'ehlers_danlos_syndrome': {'id': 'MONDO:0020066', 'name': 'ehlers danlos syndrome', 'category': 'biolink:Disease', 'cc_list': ['ehlers_danlos_syndrome']}, 'diabetes_mellitus_type_2': {'id': 'MONDO:0005148', 'name': 'diabetes mellitus type 2', 'category': 'biolink:Disease', 'cc_list': ['diabetes_mellitus_type_2']}, 'chronic_heart_failure': {'id': 'MONDO:0005009', 'name': 'chronic heart failure', 'category': 'biolink:Disease', 'cc_list': ['chronic_heart_failure']}, 'chronic_hypertension': {'id': 'UMLS:C0745114', 'name': 'chronic hypertension', 'category': 'biolink:Disease', 'cc_list': ['chronic_hypertension']}, 'osteoarthritis': {'id': 'MONDO:0005178', 'name': 'osteoarthritis', 'category': 'biolink:Disease', 'cc_list': ['osteoarthritis']}, 'chronic_obstructive_pulmonary_disease': {'id': 'MONDO:0005002', 'name': 'chronic obstr
# ...

# %%
import json
print(json.dumps(list_curies, sort_keys=True, indent=4))
# Out:
# {
#     "22q11_2_deletion_syndrome": {
#         "category": "biolink:Disease",
#         "cc_list": [
#             "22q11_2_deletion_syndrome"
#         ],
#         "id": "MONDO:0008644",
#         "name": "22q11 2 deletion syndrome"
#     },
#     "adrenal_cushing_syndrome": {
#         "category": "biolink:Disease",
#         "cc_list": [
#             "adrenal_cushing_syndrome"
#         ],
#         "id": "MONDO:0006640",
#         "name": "adrenal cushing syndrome"
#     },
#     "aicardi_syndrome": {
#         "category": "biolink:Disease",
#         "cc_list": [
#             "aicardi_syndrome"
#         ],
#         "id": "MONDO:0010568",
#         "name": "aicardi syndrome"
#     },
#     "alcohol_abuse": {
#         "category": "biolink:Disease",
#         "cc_list": [
#             "alcohol_abuse"
#         ],
#         "id": "MONDO:0002046",
#         "name": "alcohol abuse"
#     },
#     "alcoholic_liver_disease": {
#         "category": "biolink:Disease",
# ...

# %%
## Following are code for name resolver on medications

# %%
import requests

nr_url = 'https://name-resolution-sri.renci.org/lookup'
list_to_query = ['natalizumab', 'ocrelizumab', 'rituximab', 'ofatumumab', 'fingolimod', 'siponimod', 'ozanimod', 'ponesimod', 'teriflunomide', 'cladribine', 'interferon_beta_1a', 'interferon_beta_1b', 'glatiramer', 'dimethyl_fumarate', 'monomethyl_fumarate', 'diroximel_fumarate', 'elexacaftor', 'tezacaftor', 'ivacaftor', 'deoxyribonucleases', 'albuterol', 'levalbuterol', 'azithromycin', 'ipratropium', 'hydroxyurea', 'morphine', 'hydromorphone', 'ketamine', 'desmopressin', 'factor_viii', 'emicizumab', 'factor_ix', 'prednisone', 'captopril', 'fosinopril', 'lisinopril', 'quinapril', 'ramipril', 'trandolapril', 'azilsartan', 'candesartan', 'eprosartan', 'irbesartan', 'losartan', 'olmesartan', 'telmisartan', 'valsartan', 'hydralazine', 'isosorbide_dinitrate', 'vericiguat', 'acetaminophen', 'amitriptyline', 'deflazacort', 'ibuprofen', 'eteplirsen', 'golodirsen', 'casimersen', 'creatine', 'sacubitril', 'spironolactone', 'eplerenone', 'amiloride', 'bendroflumethiazide', 'chlorothiazide', 'hydrochlorothiazide', 'bumetanide', 'furosemide', 'torsemide', 'ethacrynate', 'indapamide', 'triamterene', 'finerenone', 'amlodipine', 'nifedipine', 'diltiazem', 'verapamil', 'guanfacine', 'clonidine', 'methyldopa', 'acebutolol', 'atenolol', 'bisoprolol', 'carteolol', 'carvedilol', 'esmolol', 'labetalol', 'metoprolol', 'nadolol', 'nebivolol', 'penbutolol', 'pindolol', 'propranolol', 'sotalol', 'timolol', 'doxazosin', 'terazosin', 'prazosin', 'insulin_aspart_human', 'insulin_lispro', 'insulin_glulisine_human', 'insulin_regular_human', 'insulin_glargine', 'insulin_detemir', 'metformin', 'insulin_isophane', 'lente_insulin_human', 'ultralente_insulin_human', 'canagliflozin', 'dapagliflozin', 'empagliflozin', 'ertugliflozin', 'acarbose', 'miglitol', 'alogliptin', 'linagliptin', 'saxagliptin', 'sitagliptin', 'albiglutide', 'dulaglutide', 'exenatide', 'liraglutide', 'lixisenatide', 'semaglutide', 'acetohexamide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'tolazamide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'guar_gum', 'nateglinide', 'pramlintide', 'repaglinide', 'tirzepatide', 'aducanumab', 'donepezil', 'galantamine', 'memantine', 'rivastigmine', 'tacrine', 'naproxen', 'celecoxib', 'aspirin', 'triamcinolone', 'capsaicin', 'duloxetine', 'tiotropium', 'aclidinium', 'umeclidinium', 'revefenacin', 'formoterol', 'salmeterol', 'vilanterol', 'fluticasone', 'budesonide', 'mometasone', 'beclomethasone', 'flunisolide', 'nicardipine', 'felodipine', 'nitroglycerin', 'atorvastatin', 'cerivastatin', 'fluvastatin', 'lovastatin', 'pravastatin', 'rosuvastatin', 'simvastatin', 'alteplase', 'tenecteplase', 'clevidipine', 'citalopram', 'fluoxetine', 'paroxetine', 'sertraline', 'fluvoxamine', 'escitalopram', 'cholestyramine', 'colesevelam', 'colestipol', 'choline_fenofibrate', 'fenofibrate', 'gemfibrozil', 'niacin', 'alirocumab', 'bempedoic_acid', 'evinacumab', 'evolocumab', 'inclisiran', 'lomitapide', 'mipomersen', 'policosanol', 'probucol', 'ibandronate', 'tamoxifen', 'raloxifene', 'teriparatide', 'abaloparatide', 'calcitonin', 'digoxin', 'alendronate', 'etidronate', 'pamidronate', 'risedronic_acid', 'tiludronic_acid', 'zoledronic_acid', 'brexanolone', 'bupropion', 'clomipramine', 'desipramine', 'desvenlafaxine', 'alemtuzumab', 'methotrexate', 'methylprednisolone', 'hydroxychloroquine', 'baricitinib', 'upadacitinib', 'tocilizumab', 'sarilumab', 'etanercept', 'adalimumab', 'meloxicam', 'tofacitinib', 'abatacept', 'romosozumab', 'nortriptyline', 'phenelzine', 'protriptyline', 'tranylcypromine', 'trazodone', 'trimipramine', 'tryptophan', 'venlafaxine', 'vilazodone', 'viloxazine', 'vortioxetine', 'doxepin', 'esketamine', 'imipramine', 'isocarboxazid', 'levomilnacipran', 'maprotiline', 'milnacipran', 'mirtazapine', 'nefazodone', 'leflunomide', 'naltrexone', 'fomepizole', 'topiramate', 'varenicline', 'telaprevir', 'paritaprevir', 'grazoprevir', 'voxilaprevir', 'glecaprevir', 'daclatasvir', 'elbasvir', 'ledipasvir', 'ombitasvir', 'pibrentasvir', 'velpatasvir', 'simeprevir', 'entecavir', 'tenofovir_alafenamide', 'sulfasalazine', 'sofosbuvir', 'dasabuvir', 'lamivudine', 'adefovir', 'telbivudine', 'tenofovir_disoproxil', 'interferon_alfa_2b', 'peginterferon_alfa_2a', 'lorcaserin', 'setmelanotide', 'diethylpropion', 'sibutramine', 'orlistat', 'phentermine', 'nicotine', 'acepromazine', 'amisulpride', 'aripiprazole', 'asenapine', 'brexpiprazole', 'cariprazine', 'chlorpromazine', 'clozapine', 'droperidol', 'fluphenazine', 'haloperidol', 'iloperidone', 'loxapine', 'lumateperone', 'lurasidone', 'mesoridazine', 'molindone', 'olanzapine', 'paliperidone', 'perphenazine', 'pimavanserin', 'pimozide', 'prochlorperazine', 'promazine', 'risperidone', 'sulpiride', 'thioridazine', 'thiothixene', 'trifluoperazine', 'triflupromazine', 'ziprasidone', 'buprenorphine', 'lofexidine', 'methadone', 'abacavir', 'emtricitabine', 'stavudine', 'zidovudine', 'doravirine', 'efavirenz', 'etravirine', 'nevirapine', 'atazanavir', 'darunavir', 'fosamprenavir', 'nelfinavir', 'ritonavir', 'tipranavir', 'cabotegravir', 'enfuvirtide', 'dolutegravir', 'raltegravir', 'fostemsavir', 'ibalizumab', 'terbutaline', 'indacaterol', 'olodaterol', 'omalizumab', 'mepolizumab', 'montelukast', 'zafirlukast', 'apremilast', 'golimumab', 'certolizumab_pegol', 'secukinumab', 'ixekizumab', 'brodalumab', 'guselkumab', 'risankizumab', 'tildrakizumab', 'cyclosporine', 'ketoprofen', 'diclofenac', 'azathioprine', 'ustekinumab', 'roflumilast', 'infliximab', 'tacrolimus', 'tazarotene', 'pimecrolimus', 'calcitriol',
                 'calcipotriene', 'tapinarof']
list_curies = collections.defaultdict(dict)
for item in list_to_query:
    params = {'string':item, 'limit':1} # limit -1 makes this return all available equivalent CURIEs name resolver can give            
    r = requests.post(nr_url, params=params)
    
    ## Create the curies id entry & convert the list into a string
    curies = ''.join( list( r.json().keys() ) )
    list_curies[item]["id"] = curies
    ## Remove the _ symbol from the item name to get the more readable name
    readable_name = item.replace("_", " ")
    list_curies[item]["name"] = readable_name
    ## The logic to get the most accurate category based on the found curies
    cat = "biolink:ChemicalEntity"
    
    list_curies[item]["category"] = cat
    list_curies[item]["cc_list"] = [item]

# %%
print(list_curies)
# Out:
# defaultdict(<class 'dict'>, {'natalizumab': {'id': 'MESH:D000069442', 'name': 'natalizumab', 'category': 'biolink:ChemicalEntity', 'cc_list': ['natalizumab']}, 'ocrelizumab': {'id': 'UMLS:C1882138', 'name': 'ocrelizumab', 'category': 'biolink:ChemicalEntity', 'cc_list': ['ocrelizumab']}, 'rituximab': {'id': 'CHEMBL.COMPOUND:CHEMBL1201576', 'name': 'rituximab', 'category': 'biolink:ChemicalEntity', 'cc_list': ['rituximab']}, 'ofatumumab': {'id': 'PUBCHEM.COMPOUND:8254', 'name': 'ofatumumab', 'category': 'biolink:ChemicalEntity', 'cc_list': ['ofatumumab']}, 'fingolimod': {'id': 'HMDB:HMDB0252262', 'name': 'fingolimod', 'category': 'biolink:ChemicalEntity', 'cc_list': ['fingolimod']}, 'siponimod': {'id': 'HMDB:HMDB0248844', 'name': 'siponimod', 'category': 'biolink:ChemicalEntity', 'cc_list': ['siponimod']}, 'ozanimod': {'id': 'HMDB:HMDB0256027', 'name': 'ozanimod', 'category': 'biolink:ChemicalEntity', 'cc_list': ['ozanimod']}, 'ponesimod': {'id': 'HMDB:HMDB0256699', 'name': 'ponesimod
# ...

# %%
import json
print(json.dumps(list_curies, sort_keys=True, indent=4))
# Out:
# {
#     "abacavir": {
#         "category": "biolink:ChemicalEntity",
#         "cc_list": [
#             "abacavir"
#         ],
#         "id": "HMDB:HMDB0251820",
#         "name": "abacavir"
#     },
#     "abaloparatide": {
#         "category": "biolink:ChemicalEntity",
#         "cc_list": [
#             "abaloparatide"
#         ],
#         "id": "CHEMBL.COMPOUND:CHEMBL3301581",
#         "name": "abaloparatide"
#     },
#     "abatacept": {
#         "category": "biolink:ChemicalEntity",
#         "cc_list": [
#             "abatacept"
#         ],
#         "id": "CHEMBL.COMPOUND:CHEMBL1201823",
#         "name": "abatacept"
#     },
#     "acarbose": {
#         "category": "biolink:ChemicalEntity",
#         "cc_list": [
#             "acarbose"
#         ],
#         "id": "PUBCHEM.COMPOUND:41774",
#         "name": "acarbose"
#     },
#     "acebutolol": {
#         "category": "biolink:ChemicalEntity",
#         "cc_list": [
#             "acebutolol"
#         ],
# ...
